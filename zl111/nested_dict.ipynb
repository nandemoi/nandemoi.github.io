# %% [markdown]
# 園遊會要賣水果杯，party 是一個巢狀的 dictionary，紀錄負責要買 apples 和 bananas 的同學和兩種水果的現有庫存。

# %%
party = { "workers":   {"apple":"Alice","banana":"Ben"},
          "inventory": {"apple":11 ,   "banana":8}
        }

wrk = party [...]  # 負責購買同學的 dictionary
inv = party [...]  # 現有庫存的 dictionary

a = int(input("總共需要幾個蘋果？"))
b = int(input("總共需要幾條香蕉？"))

print (wrk [...], "同學，請再買", ..., "個蘋果")
print (party ..., "同學，請再買", ..., "條香蕉") # 如果沒有指定 wrk, inv 兩個變數，直接用 party，要怎麼寫
